# %%
import cv2
import torch
from ultralytics import YOLOv10
import os
from datetime import timedelta
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.utils import ImageReader
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.utils import ImageReader
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.utils import ImageReader
from reportlab.lib import colors
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo_dataset_data_test/data_ARCG17/weights/best.pt")
# model = YOLO("G:/Мой диск/xac_r/data_ARCG9/weights/best.pt")  # build a new model from YAML
device = torch.device('cuda' )
model.to(device)
print("")

# %%
# Путь к корневой папке с видеофайлами
root_folder = 'cc'
output_folder = 'railway_output22003'
font_path = 'DejaVuSans-ExtraLight.ttf'  # Убедитесь, что путь правильный

# DejaVuSans-ExtraLight.ttf
def initialize_directories():
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    files = []
    for root, _, filenames in os.walk(root_folder):
        for filename in filenames:
            if filename.lower().endswith(('mp4', 'avi', 'mov', 'mkv')):
                files.append(os.path.join(root, filename))
    return files



def seconds_to_time(seconds):
    return str(timedelta(seconds=seconds))

def format_time(seconds):
    return time.strftime('%H:%M:%S', time.gmtime(seconds))

def process_video(file_path, model, frame_skip=20):
    cap = cv2.VideoCapture(file_path)
    if not cap.isOpened():
        print(f"Не удалось открыть видеофайл: {file_path}")
        return []

    frame_rate = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    video_duration = total_frames / frame_rate

    # Настройка записи выходного видео
    output_video_path = os.path.join(output_folder, os.path.basename(file_path))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, frame_rate, (width, height))

    frame_index = 0

    # Переменные для отслеживания нарушений
    current_violation = None
    violation_start_frame = None
    violations_logged = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_height, frame_width, _ = frame.shape
        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Выполнение трекинга объектов с помощью модели YOLOv8
        results = model(image_rgb, conf=0.3)

        # Обработка результатов
        predictions = results[0].boxes  # Предполагая, что мы хотим обработать предсказания первого изображения
        labels = predictions.cls.cpu().numpy()  # метки классов
        boxes = predictions.xyxyn.cpu().numpy()  # ограничивающие рамки
        scores = predictions.conf.cpu().numpy()  # коэффициенты уверенности

        violations = []

        for label, box, score in zip(labels, boxes, scores):
            if score >= 0.3:
                x1, y1, x2, y2 = map(float, box)
                
                # Проверка на нарушения
                if model.names[int(label)] == 'person':
                    person_box = box
                    has_vest = False
                    has_helmet = False

                    for other_label, other_box, other_score in zip(labels, boxes, scores):
                        if other_score >= 0.3 and not np.array_equal(other_box, person_box):
                            # Проверяем, пересекаются ли ограничивающие рамки человека и жилета/каски
                            if (other_box[0] < person_box[2] and other_box[2] > person_box[0] and 
                                other_box[1] < person_box[3] and other_box[3] > person_box[1]):
                                if model.names[int(other_label)] == 'vest':
                                    has_vest = True
                                if model.names[int(other_label)] == 'helmet':
                                    has_helmet = True
                                if model.names[int(other_label)] == 'heat':
                                    has_helmet = False

                    if not has_vest or not has_helmet:
                        violation_type = 'Отсутствует жилет' if not has_vest else 'Отсутствует каска'
                        violations.append({
                            'frame': frame_index,
                            'time': format_time(frame_index / frame_rate),
                            'violation': violation_type,
                            'bbox': person_box.tolist()
                        })

                        if current_violation == violation_type:
                            continue  # Continue tracking the current violation
                        else:
                            # End the current violation if it existed
                            if current_violation is not None:
                                duration = frame_index - violation_start_frame
                                if duration / frame_rate > 1:  # Duration is more than one second
                                    violations_logged.append({
                                        'file': os.path.basename(file_path),
                                        'start_time': format_time(violation_start_frame / frame_rate),
                                        'end_time': format_time((frame_index - frame_skip) / frame_rate),
                                        'violation': current_violation,
                                        'frame': violation_start_frame
                                    })
                            # Start tracking a new violation
                            current_violation = violation_type
                            violation_start_frame = frame_index

        if not violations and current_violation is not None:
            # End the current violation if it existed and wasn't tracked in this frame
            duration = frame_index - violation_start_frame
            if duration / frame_rate > 1:  # Duration is more than one second
                violations_logged.append({
                    'file': os.path.basename(file_path),
                    'start_time': format_time(violation_start_frame / frame_rate),
                    'end_time': format_time((frame_index - frame_skip) / frame_rate),
                    'violation': current_violation,
                    'frame': violation_start_frame
                })
            current_violation = None
            violation_start_frame = None

        # Сохранение исходного кадра с аннотациями
        for violation in violations:
            x1, y1, x2, y2 = map(int, [violation['bbox'][0] * frame_width, violation['bbox'][1] * frame_height, violation['bbox'][2] * frame_width, violation['bbox'][3] * frame_height])
            cropped_person = frame[int(y1 * frame_height):int(y2 * frame_height), int(x1 * frame_width):int(x2 * frame_width)]

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)  # Красная рамка для нарушения
            cv2.putText(frame, violation['violation'], (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)  # Текст с нарушением
        
        # Запись аннотированного кадра в выходное видео
        out.write(frame)

        output_annotated_image_path = os.path.join(output_folder, 'annotated_images', f"{os.path.basename(file_path)}_frame_{frame_index}.jpg")
        os.makedirs(os.path.dirname(output_annotated_image_path), exist_ok=True)
        cv2.imwrite(output_annotated_image_path, frame)

        # Увеличение индекса кадра на заданное значение frame_skip
        frame_index += frame_skip

    cap.release()
    out.release()
    print(f"Обработка завершена для видео: {file_path}")
    return violations_logged

def save_to_excel(violations, excel_path):
    df = pd.DataFrame(violations, columns=['file', 'start_time', 'end_time', 'violation'])
    df.to_excel(excel_path, index=False)
font_path = 'DejaVuSans-ExtraLight.ttf'  # Убедитесь, что путь правильный

def create_violation_chart(violations):
    # Extract violation types
    violation_types = [violation['violation'] for violation in violations]
    
    # Count each type of violation
    violation_counts = pd.Series(violation_types).value_counts()
    
    # Plot the violation counts
    plt.figure(figsize=(10, 6))
    violation_counts.plot(kind='bar', color='skyblue')
    plt.title('Types of Violations')
    plt.xlabel('Violation Type')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    chart_path = 'violation_chart.png'
    plt.savefig(chart_path)
    plt.close()
    return chart_path

def create_violation_chart(violations):
    # Extract violation types
    violation_types = [violation['violation'] for violation in violations]
    
    # Count each type of violation
    violation_counts = pd.Series(violation_types).value_counts()
    
    # Plot the violation counts
    plt.figure(figsize=(10, 6))
    violation_counts.plot(kind='bar', color='skyblue')
    plt.title('Types of Violations')
    plt.xlabel('Violation Type')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    chart_path = 'violation_chart.png'
    plt.savefig(chart_path)
    plt.close()
    return chart_path

def create_pdf_report(violations, output_pdf_path, chart_path):
    doc = SimpleDocTemplate(output_pdf_path, pagesize=letter)
    elements = []

    styles = getSampleStyleSheet()
    title_style = styles['Title']
    title_style.fontSize = 24
    title_style.textColor = colors.darkblue

    normal_style = styles['Normal']
    normal_style.fontSize = 12
    normal_style.leading = 14

    elements.append(Paragraph("Report of Violations", title_style))
    elements.append(Spacer(1, 20))

    # Add introduction about the report's purpose
    intro_text = ("This report provides an overview of safety violations detected in the analyzed videos. "
                  "The main purpose is to identify areas of improvement for safety compliance. "
                  "The chart below shows the frequency of different types of violations.")
    elements.append(Paragraph(intro_text, normal_style))
    elements.append(Spacer(1, 20))

    # Embed the violation chart at the beginning and align it to the left
    if os.path.exists(chart_path):
        elements.append(Image(chart_path, width=500, height=300))
        elements.append(Spacer(1, 40))

    for violation in violations:
        file_text = f"File: {violation['file']}"
        start_time_text = f"Start Time: {violation['start_time']}"
        end_time_text = f"End Time: {violation['end_time']}"
        violation_text = f"Violation: {violation['violation']}"

        text_data = [
            Paragraph(file_text, normal_style),
            Paragraph(start_time_text, normal_style),
            Paragraph(end_time_text, normal_style),
            Paragraph(violation_text, normal_style)
        ]

        image_folder = os.path.join(output_folder, 'annotated_images')
        image_name = f"{violation['file']}_frame_{violation.get('frame', '')}.jpg"
        image_path = os.path.join(image_folder, image_name)

        if os.path.exists(image_path):
            img = Image(image_path, width=200, height=150)
            img.hAlign = 'LEFT'
            table_data = [
                [text_data, img]
            ]
            table = Table(table_data, colWidths=[350, 200])
            table.setStyle(TableStyle([
                ('VALIGN', (0, 0), (0, 0), 'TOP')
            ]))
            elements.append(table)
            elements.append(Spacer(1, 20))
        else:
            print(f"Image not found: {image_path}")
            for paragraph in text_data:
                elements.append(paragraph)
            elements.append(Spacer(1, 20))

    doc.build(elements)
    print(f"PDF report created: {output_pdf_path}")

def main():
    initialize_directories()
    files = initialize_directories()


    all_violations = []

    for file_path in files:
        violations = process_video(file_path, model)
        all_violations.extend(violations)

    print(all_violations) 

    save_to_excel(all_violations, 'fraudssss.xlsx')
    return all_violations

 
b=main()
chart_path = create_violation_chart(b)  # Generate the chart
create_pdf_report(b, 'frauds_repor2tdf.pdf', chart_path)
print("Все видео были обработаны и результаты сохранены в Excel файл и PDF отчет.")
# Out:
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 95.2ms
# Speed: 5.0ms preprocess, 95.2ms inference, 26.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 28.1ms
# Speed: 3.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 27.1ms
# Speed: 3.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 27.1ms
# Speed: 3.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 28.0ms
# Speed: 2.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 26.6ms
# Speed: 5.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 27.2ms
# Speed: 2.1ms preprocess, 27.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 27.7ms
# Speed: 2.4ms preprocess, 27.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 26.9ms
# Speed: 4.1ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 25.6ms
# Speed: 3.0ms preprocess, 25.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 26.1ms
# Speed: 2.5ms preprocess, 26.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 26.0ms
# Speed: 2.7ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 24.8ms
# Speed: 3.0ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 24.2ms
# Speed: 3.8ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 24.6ms
# Speed: 3.0ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 25.1ms
# Speed: 2.2ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 trains, 24.4ms
# Speed: 2.2ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 25.2ms
# Speed: 3.0ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 24.6ms
# Speed: 3.0ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 trains, 25.0ms
# Speed: 2.1ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 25.1ms
# Speed: 3.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 25.2ms
# Speed: 2.1ms preprocess, 25.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 25.1ms
# Speed: 3.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 24.8ms
# Speed: 3.4ms preprocess, 24.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 technic, 2 trains, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 24.8ms
# Speed: 3.0ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 24.6ms
# Speed: 3.3ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 24.3ms
# Speed: 2.5ms preprocess, 24.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 3 trains, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 25.1ms
# Speed: 3.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 25.2ms
# Speed: 2.2ms preprocess, 25.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 1 vest, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 vest, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.8ms
# Speed: 3.0ms preprocess, 23.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 25.4ms
# Speed: 3.0ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.3ms
# Speed: 3.0ms preprocess, 24.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 25.1ms
# Speed: 3.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 25.4ms
# Speed: 3.0ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.3ms
# Speed: 2.0ms preprocess, 24.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.0ms
# Speed: 6.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.6ms
# Speed: 3.0ms preprocess, 22.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.5ms
# Speed: 5.0ms preprocess, 22.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.3ms
# Speed: 5.0ms preprocess, 23.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 technics, 2 trains, 1 vest, 22.6ms
# Speed: 4.0ms preprocess, 22.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.7ms
# Speed: 2.2ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 1 vest, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 1 vest, 23.5ms
# Speed: 2.5ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 1 vest, 24.0ms
# Speed: 2.1ms preprocess, 24.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 22.6ms
# Speed: 4.0ms preprocess, 22.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 24.1ms
# Speed: 2.1ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.0ms
# Speed: 3.4ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.4ms
# Speed: 3.2ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.5ms
# Speed: 2.5ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 3 trains, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.6ms
# Speed: 2.0ms preprocess, 22.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.6ms
# Speed: 6.0ms preprocess, 22.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.3ms
# Speed: 3.0ms preprocess, 22.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 24.3ms
# Speed: 2.0ms preprocess, 24.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.5ms
# Speed: 3.1ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.6ms
# Speed: 5.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 1 train, 1 vest, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.6ms
# Speed: 4.0ms preprocess, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.1ms
# Speed: 2.1ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.8ms
# Speed: 4.0ms preprocess, 23.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.5ms
# Speed: 2.2ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.2ms
# Speed: 3.5ms preprocess, 23.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.1ms
# Speed: 2.5ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 24.1ms
# Speed: 2.4ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 vest, 23.3ms
# Speed: 3.1ms preprocess, 23.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 vest, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 vest, 23.7ms
# Speed: 3.0ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 vest, 23.3ms
# Speed: 4.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 22.6ms
# Speed: 3.0ms preprocess, 22.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 trains, 1 vest, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 1 vest, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 23.7ms
# Speed: 3.0ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 2 trains, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 1 vest, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 3 trains, 1 vest, 23.0ms
# Speed: 2.3ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 23.3ms
# Speed: 5.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 1 vest, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 1 vest, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 2 trains, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 technic, 1 train, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 technic, 3 trains, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 technic, 2 trains, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.6ms
# Speed: 2.4ms preprocess, 22.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 2 trains, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.1ms
# Speed: 5.0ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.9ms
# Speed: 3.3ms preprocess, 22.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22.9ms
# Speed: 3.2ms preprocess, 22.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 22.8ms
# Speed: 6.0ms preprocess, 22.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 head, 1 person, 1 train, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.8ms
# Speed: 5.5ms preprocess, 22.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.2ms
# Speed: 3.0ms preprocess, 23.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.0ms
# Speed: 4.5ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.9ms
# Speed: 2.5ms preprocess, 22.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 4.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.7ms
# Speed: 3.0ms preprocess, 23.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.4ms
# Speed: 1.5ms preprocess, 23.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.7ms
# Speed: 3.5ms preprocess, 22.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.6ms
# Speed: 3.0ms preprocess, 22.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.5ms
# Speed: 3.0ms preprocess, 22.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 6.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.3ms
# Speed: 2.0ms preprocess, 24.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.4ms
# Speed: 3.0ms preprocess, 22.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.2ms
# Speed: 5.0ms preprocess, 23.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.2ms
# Speed: 3.0ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.6ms
# Speed: 3.0ms preprocess, 22.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.8ms
# Speed: 3.0ms preprocess, 23.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.4ms
# Speed: 3.0ms preprocess, 22.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 5.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.4ms
# Speed: 3.0ms preprocess, 22.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 5.0ms preprocess, 23.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.2ms
# Speed: 3.0ms preprocess, 23.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.3ms
# Speed: 3.0ms preprocess, 22.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 train, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 train, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 train, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 train, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.8ms
# Speed: 5.0ms preprocess, 22.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 train, 24.1ms
# Speed: 2.5ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 person, 1 train, 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 person, 1 train, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 person, 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 2.5ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 helmet, 1 train, 23.6ms
# Speed: 5.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.2ms
# Speed: 3.5ms preprocess, 24.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23.3ms
# Speed: 4.0ms preprocess, 23.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ...
#
# 0: 384x640 1 person, 2 trains, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.1ms
# Speed: 3.1ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 23.1ms
# Speed: 5.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 22.6ms
# Speed: 3.0ms preprocess, 22.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.9ms
# Speed: 2.5ms preprocess, 22.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 trains, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 3.1ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.3ms
# Speed: 2.5ms preprocess, 24.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.8ms
# Speed: 3.1ms preprocess, 22.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.4ms
# Speed: 2.2ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.2ms
# Speed: 6.1ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.9ms
# Speed: 3.2ms preprocess, 22.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.8ms
# Speed: 5.0ms preprocess, 22.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.8ms
# Speed: 3.3ms preprocess, 22.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.3ms
# Speed: 2.2ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.5ms
# Speed: 3.0ms preprocess, 22.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.5ms
# Speed: 2.1ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.1ms
# Speed: 4.0ms preprocess, 24.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.2ms
# Speed: 3.4ms preprocess, 23.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.9ms
# Speed: 2.3ms preprocess, 23.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 4.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.4ms
# Speed: 3.0ms preprocess, 22.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.7ms
# Speed: 3.0ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.3ms
# Speed: 4.5ms preprocess, 23.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.9ms
# Speed: 3.7ms preprocess, 22.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.3ms
# Speed: 2.0ms preprocess, 24.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 22.6ms
# Speed: 3.0ms preprocess, 22.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.7ms
# Speed: 4.0ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 6.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.8ms
# Speed: 3.1ms preprocess, 22.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 23.6ms
# Speed: 2.2ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Обработка завершена для видео: cc\VID_20240311_154731.mp4
# [{'file': 'VID_20240311_154731.mp4', 'start_time': '00:00:00', 'end_time': '00:00:03', 'violation': 'Отсутствует каска', 'frame': 0}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:00:04', 'end_time': '00:00:12', 'violation': 'Отсутствует жилет', 'frame': 240}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:00:13', 'end_time': '00:00:17', 'violation': 'Отсутствует жилет', 'frame': 800}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:00:17', 'end_time': '00:00:53', 'violation': 'Отсутствует каска', 'frame': 1040}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:00:53', 'end_time': '00:00:55', 'violation': 'Отсутствует жилет', 'frame': 3200}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:00:56', 'end_time': '00:01:00', 'violation': 'Отсутствует каска', 'frame': 3380}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:01:06', 'end_time': '00:01:08', 'violation': 'Отсутствует жилет', 'frame': 4000}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:01:54', 'end_time': '00:01:57', 'violation': 'Отсутствует жилет', 'frame': 6860}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:03', 'end_time': '00:02:06', 'violation': 'Отсутствует жилет', 'frame': 7380}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:15', 'end_time': '00:02:16', 'violation': 'Отсутствует жилет', 'frame': 8140}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:18', 'end_time': '00:02:20', 'violation': 'Отсутствует жилет', 'frame': 8320}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:21', 'end_time': '00:02:23', 'violation': 'Отсутствует жилет', 'frame': 8480}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:24', 'end_time': '00:02:26', 'violation': 'Отсутствует жилет', 'frame': 8660}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:26', 'end_time': '00:02:29', 'violation': 'Отсутствует каска', 'frame': 8800}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:37', 'end_time': '00:02:38', 'violation': 'Отсутствует каска', 'frame': 9460}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:54', 'end_time': '00:02:56', 'violation': 'Отсутствует жилет', 'frame': 10480}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:02:56', 'end_time': '00:03:00', 'violation': 'Отсутствует жилет', 'frame': 10600}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:09', 'end_time': '00:03:10', 'violation': 'Отсутствует жилет', 'frame': 11360}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:17', 'end_time': '00:03:19', 'violation': 'Отсутствует жилет', 'frame': 11840}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:20', 'end_time': '00:03:24', 'violation': 'Отсутствует жилет', 'frame': 12000}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:29', 'end_time': '00:03:30', 'violation': 'Отсутствует каска', 'frame': 12580}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:32', 'end_time': '00:03:34', 'violation': 'Отсутствует жилет', 'frame': 12720}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:38', 'end_time': '00:03:39', 'violation': 'Отсутствует жилет', 'frame': 13120}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:41', 'end_time': '00:03:42', 'violation': 'Отсутствует жилет', 'frame': 13260}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:44', 'end_time': '00:03:54', 'violation': 'Отсутствует каска', 'frame': 13440}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:03:58', 'end_time': '00:04:02', 'violation': 'Отсутствует каска', 'frame': 14300}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:04:02', 'end_time': '00:04:04', 'violation': 'Отсутствует каска', 'frame': 14560}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:05:04', 'end_time': '00:05:13', 'violation': 'Отсутствует жилет', 'frame': 18240}, {'file': 'VID_20240311_154731.mp4', 'start_time': '00:05:13', 'end_time': '00:05:14', 'violation': 'Отсутствует каска', 'frame': 18820}, {'file': 'VID_20240311_154731.mp4', 'start_tim ...
# PDF report created: frauds_repor2tdf.pdf
# Все видео были обработаны и результаты сохранены в Excel файл и PDF отчет.
